# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/dhana/Downloads/cleaned data/LARPDatabase_2015.csv")

# %%
data
# Out:
#        Unnamed: 0        MANAGEMENT          VESSEL             REF NO  \
# 0               0    SMPL - Chennai    NANYANG STAR    LR/NAST/2018/98
# 1               1    SMPL - Chennai      DEE4 BIRCH   LR/FRHA/2018/152
# 2               2    SMPL - Chennai    NANYANG STAR   LR/NAST/2018/153
# 3               3    SMPL - Chennai  VELOS SAPPHIRE  LR/GRVIC/2015/106
# 4               4  SMSL - Singapore         BENFICA     LR/BNFC/2018/3
# ...           ...               ...             ...                ...
# 61045       61068  SMSL - Singapore    BULK HOLLAND   LR/BUHD/2018/126
# 61046       61069    SMPL - Chennai      GAS STELLA    LR/STGS/2018/81
# 61047       61070    SMPL - Chennai     APL FLORIDA    LR/AFLO/2019/85
# 61048       61071    SMPL - Chennai      DEE4 CEDAR   LR/ORST/2018/283
# 61049       61072    SMPL - Chennai         CASTARA    LR/CAST/2019/47
#
#                OCCURRENCE DATE    STATUS  \
# 0      2018-04-22 03:05:14.000  Accepted
# ...

# %%
data = data.drop(columns=['Unnamed: 0'])

# %%
data.isnull().sum()
# Out:
# MANAGEMENT                  966
# VESSEL                      966
# REF NO                        0
# OCCURRENCE DATE               0
# STATUS                        0
# AREA OF CONCERN           21144
# DESCRIPTION                  17
# IMMEDIATE ACTION TAKEN     7756
# CATEGORY                      0
# WORK EQUIPMENT            54445
# LARP PROCEDURE            34363
# LARP SAFETY DEVICE        54339
# WORK ENVIRONMENT          56635
# HOUSE KEEPING             54574
# PERMIT TO WORK            60379
# LARP PPE                  52753
# WORK POSITION             53365
# REPORTED BY                8957
# CLOSURE REMARK            55449
# CLOSURE DATE              55443
# CLOSED BY                 55444
# dtype: int64

# %%
data['MANAGEMENT'].isnull().sum()
# Out:
# np.int64(966)

# %%
data['MANAGEMENT'].head(10)
# Out:
# 0      SMPL - Chennai
# 1      SMPL - Chennai
# 2      SMPL - Chennai
# 3      SMPL - Chennai
# 4    SMSL - Singapore
# 5      SMPL - Chennai
# 6    SMSL - Singapore
# 7         SOS - Kochi
# 8      SMPL - Chennai
# 9      SMPL - Chennai
# Name: MANAGEMENT, dtype: object

# %%
data['MANAGEMENT'].value_counts()
# Out:
# MANAGEMENT
# SMPL - Chennai      42367
# SMSL - Singapore     9069
# SNSPL - Pune         5029
# SOS - Kochi          3619
# Name: count, dtype: int64

# %%
data['MANAGEMENT'] = data['MANAGEMENT'].str.strip()

# %%
data['MANAGEMENT'] = data['MANAGEMENT'].fillna('Unknown')

# %%
data['VESSEL'].head()
# Out:
# 0      NANYANG STAR
# 1        DEE4 BIRCH
# 2      NANYANG STAR
# 3    VELOS SAPPHIRE
# 4           BENFICA
# Name: VESSEL, dtype: object

# %%
data['VESSEL'].value_counts()
# Out:
# VESSEL
# BENFICA          1142
# APL ANTWERP      1115
# SEROJA ENAM       885
# APL OREGON        884
# DEE4 CEDAR        884
#                  ...
# NORD NEPTUNE        3
# EHIME QUEEN         2
# PACIFIC SOUTH       2
# NORD QUEBEC         2
# WESTMINSTER         1
# Name: count, Length: 274, dtype: int64

# %%
data['VESSEL'] = data['VESSEL'].str.strip()

# %%
data['VESSEL'] = data['VESSEL'].fillna('Unknown Vessel')

# %%
data['REF NO'].head()
# Out:
# 0      LR/NAST/2018/98
# 1     LR/FRHA/2018/152
# 2     LR/NAST/2018/153
# 3    LR/GRVIC/2015/106
# 4       LR/BNFC/2018/3
# Name: REF NO, dtype: object

# %%
data['REF NO'].duplicated().sum()
# Out:
# np.int64(0)

# %%
data['REF NO'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['REF NO'] = data['REF NO'].str.strip()

# %%
data['REF NO'].head(10)
# Out:
# 0      LR/NAST/2018/98
# 1     LR/FRHA/2018/152
# 2     LR/NAST/2018/153
# 3    LR/GRVIC/2015/106
# 4       LR/BNFC/2018/3
# 5     LR/GRIV/2017/119
# 6      LR/HAKA/2017/10
# 7      LR/SVIS/2017/93
# 8    LR/TRIDE/2015/102
# 9      LR/ANBU/2018/14
# Name: REF NO, dtype: object

# %%
data['OCCURRENCE DATE'].head()
# Out:
# 0    2018-04-22 03:05:14.000
# 1    2018-08-18 09:21:47.000
# 2    2018-05-20 08:35:46.000
# 3    2015-12-07 09:54:27.000
# 4    2018-01-16 10:45:21.000
# Name: OCCURRENCE DATE, dtype: object

# %%
data['OCCURRENCE DATE'] = pd.to_datetime(data['OCCURRENCE DATE'], errors='coerce')

# %%
data['OCCURRENCE DATE'].head()
# Out:
# 0   2018-04-22 03:05:14
# 1   2018-08-18 09:21:47
# 2   2018-05-20 08:35:46
# 3   2015-12-07 09:54:27
# 4   2018-01-16 10:45:21
# Name: OCCURRENCE DATE, dtype: datetime64[ns]

# %%
data['STATUS'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 61050 entries, 0 to 61049
# Series name: STATUS
# Non-Null Count  Dtype
# --------------  -----
# 61050 non-null  object
# dtypes: object(1)
# memory usage: 477.1+ KB

# %%
data['STATUS'].unique()
# Out:
# array(['Accepted', 'Open', 'Rejected'], dtype=object)

# %%
data['STATUS'].value_counts()
# Out:
# STATUS
# Accepted    57159
# Open         3521
# Rejected      370
# Name: count, dtype: int64

# %%
data['STATUS'].isnull().sum()
# Out:
# np.int64(0)

# %%
(data['STATUS'].value_counts(normalize=True) * 100).round(2)
# Out:
# STATUS
# Accepted    93.63
# Open         5.77
# Rejected     0.61
# Name: proportion, dtype: float64

# %%
data['AREA OF CONCERN'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 61050 entries, 0 to 61049
# Series name: AREA OF CONCERN
# Non-Null Count  Dtype
# --------------  -----
# 39906 non-null  object
# dtypes: object(1)
# memory usage: 477.1+ KB

# %%
data['AREA OF CONCERN'].head(10)
# Out:
# 0    Safety Management (LSA & FFA) and security - C...
# 1    Safety Management (LSA & FFA) and security - C...
# 2             General Appearance and condition - Ch 12
# 3    Safety Management (LSA & FFA) and security - C...
# 4    Safety Management (LSA & FFA) and security - C...
# 5    Safety Management (LSA & FFA) and security - C...
# 6    Safety Management (LSA & FFA) and security - C...
# 7    Ch V/Safety Management- (Reporting- LARP, Near...
# 8                                                  NaN
# 9                                                  NaN
# Name: AREA OF CONCERN, dtype: object

# %%
data['AREA OF CONCERN'].isnull().sum()
# Out:
# np.int64(21144)

# %%
data['AREA OF CONCERN'] = data['AREA OF CONCERN'].fillna('Unknown')

# %%
data['AREA OF CONCERN'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['DESCRIPTION'].info()
data['DESCRIPTION'].head()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 61050 entries, 0 to 61049
# Series name: DESCRIPTION
# Non-Null Count  Dtype
# --------------  -----
# 61033 non-null  object
# dtypes: object(1)
# memory usage: 477.1+ KB
# 0     Personnel Entering Battery room without infor...
# 1    EXPIRED FOOD IN ECR WAS FOUND BEING USED. IMME...
# 2    during drill found SCBA bottles pressure less ...
# 3    50 ltrs gear oil in half cut drum left open on...
# 4    Deck crew properly secured the hydroblast mach...
# Name: DESCRIPTION, dtype: object

# %%
data['DESCRIPTION'].isnull().sum()
# Out:
# np.int64(17)

# %%
data['DESCRIPTION'] = data['DESCRIPTION'].fillna("No Description Provided")

# %%
data['DESCRIPTION'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['DESCRIPTION'] = data['DESCRIPTION'].str.strip()

# %%
data['DESCRIPTION'].dtype
# Out:
# dtype('O')

# %%
data['IMMEDIATE ACTION TAKEN'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 61050 entries, 0 to 61049
# Series name: IMMEDIATE ACTION TAKEN
# Non-Null Count  Dtype
# --------------  -----
# 53294 non-null  object
# dtypes: object(1)
# memory usage: 477.1+ KB

# %%
data['IMMEDIATE ACTION TAKEN'].isnull().sum()
# Out:
# np.int64(7756)

# %%
data['IMMEDIATE ACTION TAKEN'] = data['IMMEDIATE ACTION TAKEN'].fillna("No Action Reported")

# %%
data['IMMEDIATE ACTION TAKEN'] = data['IMMEDIATE ACTION TAKEN'].str.lstrip()

# %%
data = data.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
data['CATEGORY'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 61050 entries, 0 to 61049
# Series name: CATEGORY
# Non-Null Count  Dtype
# --------------  -----
# 61050 non-null  object
# dtypes: object(1)
# memory usage: 477.1+ KB

# %%
data['CATEGORY'].head()
# Out:
# 0    Unsafe act
# 1      Safe act
# 2    Unsafe act
# 3    Unsafe act
# 4      Safe act
# Name: CATEGORY, dtype: object

# %%
data['CATEGORY'].nunique()
# Out:
# 2

# %%
data['CATEGORY'].unique()
# Out:
# array(['Unsafe act', 'Safe act'], dtype=object)

# %%
data['CATEGORY'].value_counts()
# Out:
# CATEGORY
# Unsafe act    48465
# Safe act      12585
# Name: count, dtype: int64

# %%
data['CATEGORY'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['WORK EQUIPMENT'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: WORK EQUIPMENT, dtype: object

# %%
data['WORK EQUIPMENT'].isnull().sum()
# Out:
# np.int64(54445)

# %%
data = data.drop(columns=['WORK EQUIPMENT'])

# %%
data['LARP PROCEDURE'].head()
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3    Not followed
# 4             NaN
# Name: LARP PROCEDURE, dtype: object

# %%
data['LARP PROCEDURE'].isnull().sum()
# Out:
# np.int64(34363)

# %%
data['LARP PROCEDURE'] = data['LARP PROCEDURE'].fillna('Not Reported')

# %%
data['LARP PROCEDURE'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['LARP PROCEDURE'].value_counts()
# Out:
# LARP PROCEDURE
# Not Reported             34363
# Not followed             21791
# Not aware                 4095
# Not clearly explained      457
# Not available              344
# Name: count, dtype: int64

# %%
data['LARP SAFETY DEVICE'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: LARP SAFETY DEVICE, dtype: object

# %%
data['LARP SAFETY DEVICE'].isnull().sum()
# Out:
# np.int64(54339)

# %%
data.drop(columns=['LARP SAFETY DEVICE'], inplace=True)

# %%
data['WORK ENVIRONMENT'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: WORK ENVIRONMENT, dtype: object

# %%
data['WORK ENVIRONMENT'].isnull().sum()
# Out:
# np.int64(56635)

# %%
data.drop(columns=['WORK ENVIRONMENT'], inplace=True)

# %%
data['HOUSE KEEPING'].head()
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3    Not secured
# 4            NaN
# Name: HOUSE KEEPING, dtype: object

# %%
data['HOUSE KEEPING'].isnull().sum()
# Out:
# np.int64(54574)

# %%
data.drop(columns=['HOUSE KEEPING'], inplace=True)

# %%
data['PERMIT TO WORK'].isnull().sum()
# Out:
# np.int64(60379)

# %%
data.drop(columns=['PERMIT TO WORK'], inplace=True)

# %%
data['LARP PPE'].isnull().sum()
# Out:
# np.int64(52753)

# %%
data['LARP PPE'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 61050 entries, 0 to 61049
# Series name: LARP PPE
# Non-Null Count  Dtype
# --------------  -----
# 8297 non-null   object
# dtypes: object(1)
# memory usage: 477.1+ KB

# %%
data.drop(columns=['LARP PPE'], inplace=True)

# %%
data['WORK POSITION'].isnull().sum()
# Out:
# np.int64(53365)

# %%
data.drop(columns=['WORK POSITION'], inplace=True)

# %%
data['REPORTED BY'].isnull().sum()
# Out:
# np.int64(8957)

# %%
data['REPORTED BY'].head(10)
# Out:
# 0    Arun Kumar Moorthy
# 1                   NaN
# 2     Suresh Velayutham
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7        Kuldeep Katewa
# 8                   NaN
# 9                   NaN
# Name: REPORTED BY, dtype: object

# %%
data['REPORTED BY'] = data['REPORTED BY'].fillna('Unknown Reporter')

# %%
data['REPORTED BY'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['REPORTED BY'] = data['REPORTED BY'].str.strip()

# %%
data['REPORTED BY'].value_counts()
# Out:
# REPORTED BY
# Unknown Reporter                 8957
# Neil Perez Galvadores             283
# Amit Kumar                        136
# Sumit Kumar                       128
# Abhishek Kumar                    124
#                                  ...
# Abhishek Ojha                       1
# Prasanth Sivadasan                  1
# Ganesh Pratap Singh                 1
# Satyanarayana Yelleti               1
# Tomas Leslie Catarina Pereira       1
# Name: count, Length: 6865, dtype: int64

# %%
data['CLOSURE REMARK'].isnull().sum()
# Out:
# np.int64(55449)

# %%
data.drop(columns=['CLOSURE REMARK'], inplace=True)

# %%
data['CLOSURE DATE'].isnull().sum()
# Out:
# np.int64(55443)

# %%
data['CLOSURE DATE'] = pd.to_datetime(data['CLOSURE DATE'], errors='coerce')

# %%
data['CLOSURE STATUS'] = data['CLOSURE DATE'].fillna('Not Closed Yet')

# %%
data['CLOSED BY'].isnull().sum()
# Out:
# np.int64(55444)

# %%
data.drop(columns=['CLOSED BY'], inplace=True)

# %%
data.isnull().sum()
# Out:
# MANAGEMENT                    0
# VESSEL                        0
# REF NO                        0
# OCCURRENCE DATE               0
# STATUS                        0
# AREA OF CONCERN               0
# DESCRIPTION                   0
# IMMEDIATE ACTION TAKEN        0
# CATEGORY                      0
# LARP PROCEDURE                0
# REPORTED BY                   0
# CLOSURE DATE              55443
# CLOSURE STATUS                0
# dtype: int64

# %%
data['CLOSURE STATUS'] = data['CLOSURE DATE'].isna().map({True:'Not Closed Yet', False:'Closed'})

# %%
data.isnull().sum()
# Out:
# MANAGEMENT                    0
# VESSEL                        0
# REF NO                        0
# OCCURRENCE DATE               0
# STATUS                        0
# AREA OF CONCERN               0
# DESCRIPTION                   0
# IMMEDIATE ACTION TAKEN        0
# CATEGORY                      0
# LARP PROCEDURE                0
# REPORTED BY                   0
# CLOSURE DATE              55443
# CLOSURE STATUS                0
# dtype: int64

# %%
data['CLOSURE STATUS'] = data['STATUS'].apply(lambda x: 'Closed' if x=='Closed' else 'Not Closed Yet')

# %%
data.isnull().sum()
# Out:
# MANAGEMENT                    0
# VESSEL                        0
# REF NO                        0
# OCCURRENCE DATE               0
# STATUS                        0
# AREA OF CONCERN               0
# DESCRIPTION                   0
# IMMEDIATE ACTION TAKEN        0
# CATEGORY                      0
# LARP PROCEDURE                0
# REPORTED BY                   0
# CLOSURE DATE              55443
# CLOSURE STATUS                0
# dtype: int64

# %%
data['CLOSURE DATE'] = pd.to_datetime(data['CLOSURE DATE'], errors='coerce')

# %%
data['CLOSURE STATUS'] = data['CLOSURE DATE'].isna().map({True: 'Not Closed Yet', False: 'Closed'})

# %%
data[['STATUS','CLOSURE DATE','CLOSURE STATUS']].head()
# Out:
#      STATUS CLOSURE DATE  CLOSURE STATUS
# 0  Accepted          NaT  Not Closed Yet
# 1  Accepted          NaT  Not Closed Yet
# 2  Accepted          NaT  Not Closed Yet
# 3  Accepted          NaT  Not Closed Yet
# 4  Accepted          NaT  Not Closed Yet

# %%
data.isnull().sum()
# Out:
# MANAGEMENT                    0
# VESSEL                        0
# REF NO                        0
# OCCURRENCE DATE               0
# STATUS                        0
# AREA OF CONCERN               0
# DESCRIPTION                   0
# IMMEDIATE ACTION TAKEN        0
# CATEGORY                      0
# LARP PROCEDURE                0
# REPORTED BY                   0
# CLOSURE DATE              55443
# CLOSURE STATUS                0
# dtype: int64

# %%
data['CLOSURE STATUS'] = 'Closed'
data.loc[data['CLOSURE DATE'].isna(), 'CLOSURE STATUS'] = 'Not Closed Yet'

# %%
data.isnull().sum()
# Out:
# MANAGEMENT                    0
# VESSEL                        0
# REF NO                        0
# OCCURRENCE DATE               0
# STATUS                        0
# AREA OF CONCERN               0
# DESCRIPTION                   0
# IMMEDIATE ACTION TAKEN        0
# CATEGORY                      0
# LARP PROCEDURE                0
# REPORTED BY                   0
# CLOSURE DATE              55443
# CLOSURE STATUS                0
# dtype: int64

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'LARP PROCEDURE', 'REPORTED BY', 'CLOSURE DATE', 'CLOSURE STATUS'],
#       dtype='object')

# %%
data['MANAGEMENT'].nunique()
# Out:
# 5

# %%
data['MANAGEMENT'].unique()
# Out:
# array(['SMPL - Chennai', 'SMSL - Singapore', 'SOS - Kochi', 'Unknown',
#        'SNSPL - Pune'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

ax = sns.countplot(
    y='MANAGEMENT',
    data=data,
    order=data['MANAGEMENT'].value_counts().index,
    palette='viridis'
)
for p in ax.patches:
    ax.annotate(
        f'{int(p.get_width())}',
        (p.get_width() + 50, p.get_y() + p.get_height()/2),
        va='center'
    )

plt.title("Incident Distribution by Management", fontsize=16, fontweight='bold')
plt.xlabel("Number of Incidents", fontsize=12)
plt.ylabel("Management Division", fontsize=12)

plt.grid(axis='x', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_15644\2323114723.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %%
pd.crosstab(data['MANAGEMENT'], data['CATEGORY']).plot(
    kind='bar',
    stacked=True,
    figsize=(10,6)
)
# Out:
# <Axes: xlabel='MANAGEMENT'>

# %%
pd.crosstab(data['MANAGEMENT'], data['CLOSURE STATUS'])
# Out:
# CLOSURE STATUS    Closed  Not Closed Yet
# MANAGEMENT
# SMPL - Chennai       241           42126
# SMSL - Singapore     502            8567
# SNSPL - Pune        4862             167
# SOS - Kochi            2            3617
# Unknown                0             966

# %%
sns.countplot(
    y='MANAGEMENT',
    hue='CLOSURE STATUS',
    data=data
)
# Out:
# <Axes: xlabel='count', ylabel='MANAGEMENT'>

# %%
data['VESSEL'].nunique()
# Out:
# 275

# %%
top_vessels = data['VESSEL'].value_counts().head(10)

plt.figure(figsize=(10,6))

ax = sns.barplot(
    x=top_vessels.values,
    y=top_vessels.index,
    palette='magma'
)
for i, v in enumerate(top_vessels.values):
    plt.text(v + 10, i, str(v), va='center')

plt.title("Top 10 Vessels with Highest Incidents", fontsize=16, fontweight='bold')
plt.xlabel("Number of Incidents")
plt.ylabel("Vessel")

plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_15644\3490372515.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
vessel_risk = data['VESSEL'].value_counts().reset_index()
vessel_risk.columns = ['VESSEL', 'Incident_Count']

vessel_risk.head(10)
# Out:
#            VESSEL  Incident_Count
# 0         BENFICA            1142
# 1     APL ANTWERP            1115
# 2  Unknown Vessel             966
# 3     SEROJA ENAM             885
# 4      APL OREGON             884
# 5      DEE4 CEDAR             884
# 6    MOL PRESENCE             863
# 7    SEROJA EMPAT             796
# 8     NINGBO DAWN             762
# 9  APL CALIFORNIA             709

# %%
pd.crosstab(data['VESSEL'], data['CATEGORY']).head(10).plot(
    kind='bar',
    stacked=True,
    figsize=(12,6)
)
# Out:
# <Axes: xlabel='VESSEL'>

# %%
pd.crosstab(data['VESSEL'], data['CLOSURE STATUS'])
# Out:
# CLOSURE STATUS         Closed  Not Closed Yet
# VESSEL
# ACE SPAIN                   0             104
# ADITYA                      7             262
# AFRICAN SPOONBILL           0             151
# AFRICAN TURACO              0              71
# AL-BETROLEYA                0             278
# ...                       ...             ...
# WESTMINSTER                 0               1
# X-PRESS MONTE CERVINO       1              45
# X-PRESS TAJUMULCO           0              20
# X-PRESS VESUVIO             2              13
# YERUPAJA                    6              26
#
# [275 rows x 2 columns]

# %%
data['year'] = data['OCCURRENCE DATE'].dt.year
data['month'] = data['OCCURRENCE DATE'].dt.month
data['day'] = data['OCCURRENCE DATE'].dt.day
data['weekday'] = data['OCCURRENCE DATE'].dt.day_name()

# %%
plt.figure(figsize=(10,6))
ax = sns.countplot(
    x='year',
    data=data,
    order=sorted(data['year'].dropna().unique()),
    palette='viridis'
)
for p in ax.patches:
    ax.annotate(
        f'{int(p.get_height())}',
        (p.get_x() + p.get_width()/2., p.get_height()),
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.title("Incident Distribution by Year", fontsize=16, fontweight='bold')
plt.xlabel("Year", fontsize=12)
plt.ylabel("Number of Incidents", fontsize=12)

plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_15644\1454377145.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %%
plt.figure(figsize=(10,6))

ax = sns.countplot(
    x='month',
    data=data,
    order=sorted(data['month'].dropna().unique()),
    palette='coolwarm'
)
for p in ax.patches:
    ax.annotate(
        f'{int(p.get_height())}',
        (p.get_x() + p.get_width()/2., p.get_height()),
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.title("Monthly Incident Distribution", fontsize=16, fontweight='bold')
plt.xlabel("Month", fontsize=12)
plt.ylabel("Number of Incidents", fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_15644\3412192061.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %%
pivot = pd.pivot_table(
    data,
    values='CATEGORY',
    index='month',
    columns='year',
    aggfunc='count'
)

# %%
plt.figure(figsize=(8,6))

sns.heatmap(pivot, cmap='Reds', annot=True, fmt='g')

plt.title("Incident Heatmap (Month vs Year)")
plt.show()

# %%
plt.figure(figsize=(8,5))

ax = sns.countplot(
    x='STATUS',
    data=data,
    palette='Set2'
)

for p in ax.patches:
    ax.annotate(
        f'{int(p.get_height())}',
        (p.get_x() + p.get_width()/2., p.get_height()),
        ha='center',
        va='bottom'
    )

plt.title("Incident Status Distribution", fontsize=16, fontweight='bold')
plt.xlabel("Status")
plt.ylabel("Number of Incidents")

plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_15644\4111863193.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %%
status_counts = data['STATUS'].value_counts()

plt.figure(figsize=(7,7))

plt.pie(
    status_counts,
    autopct='%1.1f%%',
    startangle=90,
    colors=['#66c2a5','#fc8d62']
)

plt.legend(status_counts.index, title="Status")

plt.title("Incident Status Distribution")

plt.tight_layout()

plt.show()

# %%
data['AREA OF CONCERN'].unique()
# Out:
# array(['Safety Management (LSA & FFA) and security - Ch 5 d. COWSP',
#        'General Appearance and condition - Ch 12',
#        'Ch V/Safety Management- (Reporting- LARP, Near Misses, Incident Investigations and PSC etc.)',
#        'Unknown',
#        'Safety Management (LSA & FFA) and security - Ch 5 a. LSA',
#        'Ch V/Safety Management- (Risk assessment, PTW, Checklist & Isolation)',
#        'Cargo and ballast system - Ch 8 c. Monitoring',
#        'structurall condition PMS - Ch 7 a. Planned Maintenance',
#        'Safety Management (LSA & FFA) and security - Ch 5 c. Security',
#        'Engine and Steering compartments - Ch 11',
#        'Crew Management - Fatigue, Language, D&A - Ch 3',
#        'Environment (Pollution prevention) - Ch 6 b. Annex2',
#        'Ch V/Safety Management- (Lifesaving Equipment)',
#        'Ch XI/ General App & Condition-  (Structural Condition)',
#        'Ch V/Safety Management- (Safe Access)',
#        'Ch III/Crew Management (Others)',
# ...

# %%
pd.crosstab(data['AREA OF CONCERN'], data['CATEGORY'])
# Out:
# CATEGORY                                            Safe act  Unsafe act
# AREA OF CONCERN
# Cargo and ballast system - Ch 8 a. Plan                   21          49
# Cargo and ballast system - Ch 8 b. Execution              53         202
# Cargo and ballast system - Ch 8 c. Monitoring            101         452
# Certification (National, International and clas...         0          10
# Ch I GENERAL INFORMATION                                 431        1755
# ...                                                      ...         ...
# Safety Management (LSA & FFA) and security - Ch...        99         757
# Safety Management (LSA & FFA) and security - Ch...       100         517
# Safety Management (LSA & FFA) and security - Ch...      1802        7785
# Unknown                                                 4898       16246
# structurall condition PMS - Ch 7 a. Planned Mai...        47         336
#
# [118 rows x 2 columns]

# %%
pd.crosstab(data['MANAGEMENT'], data['AREA OF CONCERN'])
# Out:
# AREA OF CONCERN   Cargo and ballast system - Ch 8 a. Plan  \
# MANAGEMENT
# SMPL - Chennai                                         46
# SMSL - Singapore                                       20
# SNSPL - Pune                                            3
# SOS - Kochi                                             1
# Unknown                                                 0
#
# AREA OF CONCERN   Cargo and ballast system - Ch 8 b. Execution  \
# MANAGEMENT
# SMPL - Chennai                                             155
# SMSL - Singapore                                            78
# SNSPL - Pune                                                21
# SOS - Kochi                                                  1
# Unknown                                                      0
#
# AREA OF CONCERN   Cargo and ballast system - Ch 8 c. Monitoring  \
# MANAGEMENT
# SMPL - Chennai                                              429
# SMSL - Singapore                                             96
# ...

# %%
pd.crosstab(data['AREA OF CONCERN'], data['STATUS'])
# Out:
# STATUS                                              Accepted  Open  Rejected
# AREA OF CONCERN
# Cargo and ballast system - Ch 8 a. Plan                   69     1         0
# Cargo and ballast system - Ch 8 b. Execution             249     5         1
# Cargo and ballast system - Ch 8 c. Monitoring            540    12         1
# Certification (National, International and clas...         9     0         1
# Ch I GENERAL INFORMATION                                2174     4         8
# ...                                                      ...   ...       ...
# Safety Management (LSA & FFA) and security - Ch...       840    16         0
# Safety Management (LSA & FFA) and security - Ch...       609     7         1
# Safety Management (LSA & FFA) and security - Ch...      9355   212        20
# Unknown                                                18104  2749       291
# structurall condition PMS - Ch 7 a. Planned Mai...       365    18         0
#
# [118 rows x 3 columns]

# %%
pd.crosstab(data['MANAGEMENT'], data['IMMEDIATE ACTION TAKEN'])
# Out:
# IMMEDIATE ACTION TAKEN     \
# MANAGEMENT
# SMPL - Chennai          3
# SMSL - Singapore        1
# SNSPL - Pune            0
# SOS - Kochi             0
# Unknown                 6
#
# IMMEDIATE ACTION TAKEN  " Immediately stopped painting by senior officer and the paint got removed by the crew and explained him the consequences. "  \
# MANAGEMENT
# SMPL - Chennai                                                          0
# SMSL - Singapore                                                        0
# SNSPL - Pune                                                            0
# SOS - Kochi                                                             1
# Unknown                                                                 0
#
# IMMEDIATE ACTION TAKEN  "A" distance of both the windlass brake spindles were adjusted to between 205~215 mm. Pls find attached photos  \
# MANAGEMENT
# SMPL - Chennai                                                          1
# ...

# %%
data['CATEGORY'].unique()
# Out:
# array(['Unsafe act', 'Safe act'], dtype=object)

# %%
plt.figure(figsize=(10,6))

ax = sns.countplot(
    y='CATEGORY',
    data=data,
    order=data['CATEGORY'].value_counts().index,
    palette='Set2'
)
for p in ax.patches:
    ax.annotate(
        f'{int(p.get_width())}',
        (p.get_width(), p.get_y() + p.get_height()/2),
        va='center'
    )

plt.title("Incident Distribution by Category", fontsize=16, fontweight='bold')
plt.xlabel("Number of Incidents")
plt.ylabel("Category")

plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_15644\2424171621.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %%
pd.crosstab(data['MANAGEMENT'], data['CATEGORY'])
# Out:
# CATEGORY          Safe act  Unsafe act
# MANAGEMENT
# SMPL - Chennai        7492       34875
# SMSL - Singapore      2776        6293
# SNSPL - Pune           872        4157
# SOS - Kochi            957        2662
# Unknown                488         478

# %%
pd.crosstab(data['MANAGEMENT'], data['CATEGORY']).plot(
    kind='bar',
    stacked=True,
    figsize=(12,6)
)
# Out:
# <Axes: xlabel='MANAGEMENT'>

# %%
pd.crosstab(data['VESSEL'], data['CATEGORY'])
# Out:
# CATEGORY               Safe act  Unsafe act
# VESSEL
# ACE SPAIN                    14          90
# ADITYA                       33         236
# AFRICAN SPOONBILL           123          28
# AFRICAN TURACO               18          53
# AL-BETROLEYA                 36         242
# ...                         ...         ...
# WESTMINSTER                   0           1
# X-PRESS MONTE CERVINO        10          36
# X-PRESS TAJUMULCO             5          15
# X-PRESS VESUVIO               1          14
# YERUPAJA                      3          29
#
# [275 rows x 2 columns]

# %%
pd.crosstab(data['CATEGORY'], data['STATUS'])
# Out:
# STATUS      Accepted  Open  Rejected
# CATEGORY
# Safe act       11293  1145       147
# Unsafe act     45866  2376       223

# %%
pd.crosstab(data['year'], data['CATEGORY'])
# Out:
# CATEGORY  Safe act  Unsafe act
# year
# 2015           568        2654
# 2016          1214        5782
# 2017          2281        8874
# 2018          3315       13444
# 2019          5207       17711

# %%
pd.crosstab(data['year'], data['CATEGORY']).plot(
    kind='bar',
    stacked=True,
    figsize=(12,6)
)
# Out:
# <Axes: xlabel='year'>

# %%
heatmap_data = pd.crosstab(data['CATEGORY'], data['MANAGEMENT'])

plt.figure(figsize=(8,6))

sns.heatmap(heatmap_data, cmap='Reds', annot=True, fmt='g')

plt.title("Category vs Management Heatmap")

plt.show()

# %%
data['closure_year'] = data['CLOSURE DATE'].dt.year
data['closure_month'] = data['CLOSURE DATE'].dt.month

# %%
data['closure_year'].value_counts().sort_index()
# Out:
# closure_year
# 2015.0      31
# 2016.0     245
# 2017.0     810
# 2018.0    1449
# 2019.0    2490
# 2020.0     582
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x='closure_year',
    data=data,
    palette='viridis'
)

plt.title("Incidents Closed by Year")
plt.xlabel("Year")
plt.ylabel("Number of Closed Incidents")

plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.show()
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_15644\4070360393.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x='closure_month',
    data=data,
    palette='coolwarm'
)

plt.title("Monthly Incident Closure Distribution")
plt.xlabel("Month")
plt.ylabel("Number of Closed Incidents")

plt.show()
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_15644\851501750.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
data['resolution_days'] = (
    data['CLOSURE DATE'] - data['OCCURRENCE DATE']
).dt.days

# %%
data[['OCCURRENCE DATE','CLOSURE DATE','resolution_days']].head()
# Out:
#       OCCURRENCE DATE CLOSURE DATE  resolution_days
# 0 2018-04-22 03:05:14          NaT              NaN
# 1 2018-08-18 09:21:47          NaT              NaN
# 2 2018-05-20 08:35:46          NaT              NaN
# 3 2015-12-07 09:54:27          NaT              NaN
# 4 2018-01-16 10:45:21          NaT              NaN

# %%
data['CLOSURE STATUS'].unique()
# Out:
# array(['Not Closed Yet', 'Closed'], dtype=object)

# %%
plt.figure(figsize=(10,6))

ax = sns.countplot(
    x='CLOSURE STATUS',
    data=data,
    palette=['#2ecc71','#e74c3c']
)

total = len(data)

# Add count + percentage labels
for p in ax.patches:
    count = int(p.get_height())
    percentage = 100 * count / total
    
    ax.annotate(
        f'{count}\n({percentage:.1f}%)',
        (p.get_x() + p.get_width()/2., p.get_height()),
        ha='center',
        va='bottom',
        fontsize=11,
        fontweight='bold'
    )

plt.title(
    "Incident Closure Status Distribution",
    fontsize=18,
    fontweight='bold'
)

plt.xlabel("Closure Status", fontsize=12)
plt.ylabel("Number of Incidents", fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.5)

sns.despine()

plt.tight_layout()

plt.show()
# Out:
# C:\Users\dhana\AppData\Local\Temp\ipykernel_15644\2686453890.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %%
pd.crosstab(data['MANAGEMENT'], data['CLOSURE STATUS'])
# Out:
# CLOSURE STATUS    Closed  Not Closed Yet
# MANAGEMENT
# SMPL - Chennai       241           42126
# SMSL - Singapore     502            8567
# SNSPL - Pune        4862             167
# SOS - Kochi            2            3617
# Unknown                0             966

# %%
sns.countplot(
    y='MANAGEMENT',
    hue='CLOSURE STATUS',
    data=data
)
# Out:
# <Axes: xlabel='count', ylabel='MANAGEMENT'>

# %%
pd.crosstab(data['VESSEL'], data['CLOSURE STATUS'])
# Out:
# CLOSURE STATUS         Closed  Not Closed Yet
# VESSEL
# ACE SPAIN                   0             104
# ADITYA                      7             262
# AFRICAN SPOONBILL           0             151
# AFRICAN TURACO              0              71
# AL-BETROLEYA                0             278
# ...                       ...             ...
# WESTMINSTER                 0               1
# X-PRESS MONTE CERVINO       1              45
# X-PRESS TAJUMULCO           0              20
# X-PRESS VESUVIO             2              13
# YERUPAJA                    6              26
#
# [275 rows x 2 columns]
