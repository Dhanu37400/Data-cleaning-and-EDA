# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Downloads/ADIDatabase_2015.csv")

# %%
data
# Out:
#       Unnamed: 0          Vessel                         RefNO  \
# 0             60     KAILASH GAS          ADI/KAILA/2015/Apr/4
# 1             87  FALCON VICTORY          ADI/VICTO/2015/Jul/2
# 2            133   CALA PINGUINO            ADI/PIN/2015/Nov/6
# 3            134    EAST BANGKOK  ADI/BANGK-SMPL-C/2015/Nov/27
# 4            135    EAST BANGKOK  ADI/BANGK-SMPL-C/2015/Nov/28
# ...          ...             ...                           ...
# 1406        1600   MAERSK EDIRNE           ADI/MEDN/2020/May/1
# 1407        1601  SOUTHERN GLORY           ADI/SOGL/2020/May/1
# 1408        1602   LOWLANDS BLUE           ADI/LLBL/2020/May/2
# 1409        1603  VELOS SAPPHIRE           ADI/VESA/2020/May/4
# 1410        1604       BW KIZOKU           ADI/BWKI/2020/Jun/1
#
#                OccurrenceDate               ReportDate Defect Status Location  \
# 0     2015-04-13 09:15:51.000  2015-04-13 04:02:44.533        Closed      Sea
# ...

# %%
data.head()
# Out:
#    Unnamed: 0          Vessel                         RefNO  \
# 0          60     KAILASH GAS          ADI/KAILA/2015/Apr/4
# 1          87  FALCON VICTORY          ADI/VICTO/2015/Jul/2
# 2         133   CALA PINGUINO            ADI/PIN/2015/Nov/6
# 3         134    EAST BANGKOK  ADI/BANGK-SMPL-C/2015/Nov/27
# 4         135    EAST BANGKOK  ADI/BANGK-SMPL-C/2015/Nov/28
#
#             OccurrenceDate               ReportDate Defect Status Location  \
# 0  2015-04-13 09:15:51.000  2015-04-13 04:02:44.533        Closed      Sea
# 1  2015-07-19 13:00:51.000  2015-07-19 14:42:16.783        Closed     Port
# 2  2015-11-05 11:39:31.000  2015-11-05 18:39:42.603        Closed      Sea
# 3  2015-09-29 12:32:00.000  2015-11-06 12:53:35.923        Closed     Port
# 4  2015-09-11 13:04:00.000  2015-11-06 14:14:09.320  Under Review     Port
#
#          Port                                    IncidentDetails  \
# 0         NaN  At Sea it was observed that on Main Switchboar...
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate',
#        'Defect Status', 'Location', 'Port', 'IncidentDetails',
#        'IncidentEventDetails', 'ImmediateAction', 'Incident Category',
#        'Possibility Recurrence', 'AreaOfConcern',
#        'DetailedExtentofDamageInjury', 'DirectCause', 'IndirectCause',
#        'RootCause', 'Proposedcorrectiveactions', 'Corrective Action',
#        'LeariningPotential', 'SeverityOfIncident', 'RevisedIncidentCategory',
#        'Cause Analysis', 'Accident Details', 'LessionLearnt', 'ReviewComments',
#        'ClosingNote', 'ClosingDate', 'Injured Person Name',
#        'Injured Person Rank', 'OtherRank', 'OtherUser',
#        'InjuryAccidentCategory', 'Injured Part', 'Other Part'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1411 entries, 0 to 1410
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    1411 non-null   int64
#  1   Vessel                        1411 non-null   object
#  2   RefNO                         1411 non-null   object
#  3   OccurrenceDate                1411 non-null   object
#  4   ReportDate                    1411 non-null   object
#  5   Defect Status                 1411 non-null   object
#  6   Location                      1411 non-null   object
#  7   Port                          345 non-null    object
#  8   IncidentDetails               1405 non-null   object
#  9   IncidentEventDetails          1288 non-null   object
#  10  ImmediateAction               1389 non-null   object
#  11  Incident Category             1411 non-null   object
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0  IndirectCause  RootCause
# count  1411.000000            0.0        0.0
# mean    864.275691            NaN        NaN
# std     432.216194            NaN        NaN
# min      60.000000            NaN        NaN
# 25%     488.500000            NaN        NaN
# 50%     841.000000            NaN        NaN
# 75%    1251.500000            NaN        NaN
# max    1604.000000            NaN        NaN

# %%
data.isna().sum()
# Out:
# Unnamed: 0                         0
# Vessel                             0
# RefNO                              0
# OccurrenceDate                     0
# ReportDate                         0
# Defect Status                      0
# Location                           0
# Port                            1066
# IncidentDetails                    6
# IncidentEventDetails             123
# ImmediateAction                   22
# Incident Category                  0
# Possibility Recurrence            23
# AreaOfConcern                    183
# DetailedExtentofDamageInjury     206
# DirectCause                      330
# IndirectCause                   1411
# RootCause                       1411
# Proposedcorrectiveactions         59
# Corrective Action                591
# LeariningPotential               304
# SeverityOfIncident               175
# RevisedIncidentCategory         1369
# Cause Analysis                    23
# Accident Details                 916
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (1411, 36)

# %%
cols_to_drop = { 'Unnamed: 0','RootCause','RevisedIncidentCategory','ReviewComments','Injured Person Name',
       'Injured Person Rank', 'OtherRank', 'OtherUser','InjuryAccidentCategory', 'Injured Part', 'Other Part','IndirectCause'}

data.drop(columns = cols_to_drop, inplace=True)

# %%
month_map = {
    "Jan": "01", "Feb": "02", "Mar": "03", "Apr": "04",
    "May": "05", "Jun": "06", "Jul": "07", "Aug": "08",
    "Sep": "09", "Oct": "10", "Nov": "11", "Dec": "12"
}

data["RefNO"] = data["RefNO"].replace(month_map, regex=True)

# %%
data['OccurrenceDate'] = pd.to_datetime(data['OccurrenceDate'])
data['ReportDate'] = pd.to_datetime(data['ReportDate'])
data['ClosingDate'] = pd.to_datetime(data['ClosingDate'])

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                   ReportDate Defect Status Location  \
# 0    2015-04-13 04:02:44.533        Closed      Sea
# ...

# %%
data['Year'] = data['OccurrenceDate'].dt.year
data['Month'] = data['OccurrenceDate'].dt.month
data['Day'] = data['OccurrenceDate'].dt.day

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                   ReportDate Defect Status Location  \
# 0    2015-04-13 04:02:44.533        Closed      Sea
# ...

# %%
data["OccurrenceDate"] = data["OccurrenceDate"].dt.strftime("%Y-%m-%d %H:%M:%S")

# %%
data["ReportDate"] = data["ReportDate"].dt.strftime("%Y-%m-%d %H:%M:%S")

# %%
data
# Out:
#               Vessel                        RefNO       OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4  2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2  2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6  2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27  2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28  2015-09-11 13:04:00
# ...              ...                          ...                  ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1  2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1  2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2  2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4  2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1  2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data['Port'] = data['Port'].fillna('Unknown')

# %%
data
# Out:
#               Vessel                        RefNO       OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4  2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2  2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6  2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27  2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28  2015-09-11 13:04:00
# ...              ...                          ...                  ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1  2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1  2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2  2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4  2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1  2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data.columns
# Out:
# Index(['Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate', 'Defect Status',
#        'Location', 'Port', 'IncidentDetails', 'IncidentEventDetails',
#        'ImmediateAction', 'Incident Category', 'Possibility Recurrence',
#        'AreaOfConcern', 'DetailedExtentofDamageInjury', 'DirectCause',
#        'Proposedcorrectiveactions', 'Corrective Action', 'LeariningPotential',
#        'SeverityOfIncident', 'Cause Analysis', 'Accident Details',
#        'LessionLearnt', 'ClosingNote', 'ClosingDate', 'Year', 'Month', 'Day'],
#       dtype='object')

# %%
data['OccurrenceDate'] = pd.to_datetime(data['OccurrenceDate'], errors='coerce')

data['Month'] = data['OccurrenceDate'].dt.strftime('%B')

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data['IncidentDetails'].head()
# Out:
# 0    At Sea it was observed that on Main Switchboar...
# 1    Hydraulic oil spray on poop deck from hydrauli...
# 2    during the ISPS audit it was found that few of...
# 3    On 26 September 2015 we informed about main ai...
# 4    On 11 September 2015 14:30 HRS. After complete...
# Name: IncidentDetails, dtype: object

# %%
data['IncidentDetails'].isnull().sum()
# Out:
# np.int64(6)

# %%
data['IncidentDetails'] = data['IncidentDetails'].fillna('Not Mentioned')

# %%
data['IncidentDetails'] = data['IncidentDetails'].str.strip()

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data['IncidentEventDetails'].head()
# Out:
# 0    Suspect connecting bolts/nuts are not fully ti...
# 1    Vessel was receiving bunkers at Western Anchor...
# 2    Passes issued to the visitors not returned to ...
# 3    On 26 September 2015 we informed about main ai...
# 4    On 11 September 2015 14:30 HRS. After complete...
# Name: IncidentEventDetails, dtype: object

# %%
data['IncidentEventDetails'].isnull().sum()
# Out:
# np.int64(123)

# %%
data['IncidentEventDetails'] = data['IncidentEventDetails'].fillna('Not Mentioned')

# %%
data['IncidentEventDetails'] = data['IncidentEventDetails'].str.strip()

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data['ImmediateAction'].head()
# Out:
# 0    ME stopped and blackout was done to repair on ...
# 1    Framo power pack system stopped, Inlet line to...
# 2    Search carried out on board to locate the miss...
# 3    Stopped the process and necessary action was t...
# 4    Change fuel pump (move fuel pump DG3 unit 5 to...
# Name: ImmediateAction, dtype: object

# %%
data['ImmediateAction'].isnull().sum()
# Out:
# np.int64(22)

# %%
data['ImmediateAction'] = data['ImmediateAction'].fillna('No Immediate Action Mentioned')

# %%
data['ImmediateAction'] = data['ImmediateAction'].str.strip()

# %%
from collections import Counter

text = " ".join(data['ImmediateAction'])

words = text.split()

Counter(words).most_common(20)
# Out:
# [('the', 2012),
#  ('and', 1908),
#  ('to', 1472),
#  ('was', 1245),
#  ('of', 625),
#  ('for', 528),
#  ('on', 464),
#  ('with', 449),
#  ('in', 432),
#  ('from', 308),
#  ('&', 289),
#  ('were', 267),
#  ('by', 259),
#  ('aid', 224),
#  ('The', 205),
#  ('given', 199),
#  ('out', 196),
#  ('all', 188),
#  ('vessel', 185),
#  ('informed', 184)]

# %%
    data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data['IncidentEventDetails'] = data['IncidentEventDetails'].str.replace(r'^1\.', '', regex=True)

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data['IncidentDetails'] = data['IncidentDetails'].str.replace(r'^1\.', '', regex=True)

# %%
data['ImmediateAction'] = data['ImmediateAction'].str.replace(r'^1\.', '', regex=True)

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data['ImmediateAction'].head(20)
# Out:
# 0     ME stopped and blackout was done to repair on ...
# 1     Framo power pack system stopped, Inlet line to...
# 2     Search carried out on board to locate the miss...
# 3     Stopped the process and necessary action was t...
# 4     Change fuel pump (move fuel pump DG3 unit 5 to...
# 5     Temporary connected direct power to computer N...
# 6                         No Immediate Action Mentioned
# 7     INFORM CAPT. BAKSHI,LOG THE INCIDENT IN DECK O...
# 8     Informed Loading Master immediately. Loading M...
# 9     BT stopped completely to avoid further damage ...
# 10    0500 lt : After vessel all fast, for'd breast ...
# 11    Since thier was no evidence brought forward to...
# 12    Immediately informed master. Stbd side MOB mar...
# 13                 De pressurized the line immediately.
# 14    Checking of all ballast tanks. Informed Office...
# 15    we r trying our best to reverse the engines. w...
# 16    1-Immediately informed CCR to call the loading...
# ...

# %%
data.columns
# Out:
# Index(['Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate', 'Defect Status',
#        'Location', 'Port', 'IncidentDetails', 'IncidentEventDetails',
#        'ImmediateAction', 'Incident Category', 'Possibility Recurrence',
#        'AreaOfConcern', 'DetailedExtentofDamageInjury', 'DirectCause',
#        'Proposedcorrectiveactions', 'Corrective Action', 'LeariningPotential',
#        'SeverityOfIncident', 'Cause Analysis', 'Accident Details',
#        'LessionLearnt', 'ClosingNote', 'ClosingDate', 'Year', 'Month', 'Day'],
#       dtype='object')

# %%
data['Incident Category'].head()
# Out:
# 0    Marginal Or Moderate Harm
# 1    Marginal Or Moderate Harm
# 2                        Minor
# 3                        Minor
# 4    Marginal Or Moderate Harm
# Name: Incident Category, dtype: object

# %%
data['Incident Category'].unique()
# Out:
# array(['Marginal Or Moderate Harm', 'Minor',
#        'Catastrophic Or Extremely Harmful', 'Critical Or Severe Harm'],
#       dtype=object)

# %%
data['Incident Category'].value_counts()
# Out:
# Incident Category
# Minor                                911
# Marginal Or Moderate Harm            445
# Critical Or Severe Harm               41
# Catastrophic Or Extremely Harmful     14
# Name: count, dtype: int64

# %%
data['Incident Category'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Incident Category'] = data['Incident Category'].str.strip()

# %%
data['Incident Category'].value_counts().plot(kind='bar')
plt.title("Incident Category Distribution")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %%
data['Possibility Recurrence'].unique()
# Out:
# array(['Likely', 'Very Likely', 'Unlikely', 'Very Unlikely', nan],
#       dtype=object)

# %%
data['Possibility Recurrence'].value_counts()
# Out:
# Possibility Recurrence
# Unlikely         590
# Likely           341
# Very Unlikely    310
# Very Likely      147
# Name: count, dtype: int64

# %%
data['Possibility Recurrence'].isnull().sum()
# Out:
# np.int64(23)

# %%
data['Possibility Recurrence'] = data['Possibility Recurrence'].fillna('Unknown')

# %%
data['Possibility Recurrence'] = data['Possibility Recurrence'].str.strip()

# %%
data['Possibility Recurrence'].value_counts().plot(kind='bar')
plt.title("Possibility of Recurrence")
plt.xlabel("Recurrence")
plt.ylabel("Count")
plt.show()

# %%
pd.crosstab(data['Incident Category'], data['Possibility Recurrence'])
# Out:
# Possibility Recurrence             Likely  Unknown  Unlikely  Very Likely  \
# Incident Category
# Catastrophic Or Extremely Harmful       4        0         1            2
# Critical Or Severe Harm                11        1        15            4
# Marginal Or Moderate Harm             110        3       191           50
# Minor                                 216       19       383           91
#
# Possibility Recurrence             Very Unlikely
# Incident Category
# Catastrophic Or Extremely Harmful              7
# Critical Or Severe Harm                       10
# Marginal Or Moderate Harm                     91
# Minor                                        202

# %%
data['AreaOfConcern'].head()
# Out:
# 0    Engine And Steering Compartments
# 1                             Mooring
# 2                   Safety Management
# 3           Structurall Condition Pms
# 4                                 NaN
# Name: AreaOfConcern, dtype: object

# %%
data['AreaOfConcern'].dtype
# Out:
# dtype('O')

# %%
data['AreaOfConcern'].isnull().sum()
# Out:
# np.int64(183)

# %%
data['AreaOfConcern'] = data['AreaOfConcern'].fillna('Unknown')

# %%
data['AreaOfConcern'] = data['AreaOfConcern'].str.strip()

# %%
data['AreaOfConcern'].unique()
# Out:
# array(['Engine And Steering Compartments', 'Mooring', 'Safety Management',
#        'Structurall Condition Pms', 'Unknown', 'Navigation',
#        'Crew Management', 'Environment (Pollution Prevention)',
#        'Communication', 'General Appearance And Condition',
#        'Cargo And Ballast System', 'Company Documents',
#        'Maritime Security', 'General Information'], dtype=object)

# %%
data['AreaOfConcern'].value_counts(normalize=True)*100
# Out:
# AreaOfConcern
# Safety Management                     35.719348
# Mooring                               13.182140
# Unknown                               12.969525
# Engine And Steering Compartments      11.906449
# Cargo And Ballast System               8.504607
# Crew Management                        3.827073
# Navigation                             3.685330
# General Appearance And Condition       3.614458
# Environment (Pollution Prevention)     2.267895
# Structurall Condition Pms              2.126152
# Maritime Security                      0.779589
# General Information                    0.566974
# Communication                          0.496102
# Company Documents                      0.354359
# Name: proportion, dtype: float64

# %%
data['AreaOfConcern'].value_counts().plot(kind='bar')
plt.title("Area of Concern Distribution")
plt.xlabel("Area Of Concern")
plt.ylabel("Number of Incidents")
plt.show()

# %%
pd.crosstab(data['AreaOfConcern'], data['Incident Category'])
# Out:
# Incident Category                   Catastrophic Or Extremely Harmful  \
# AreaOfConcern
# Cargo And Ballast System                                            3
# Communication                                                       0
# Company Documents                                                   0
# Crew Management                                                     1
# Engine And Steering Compartments                                    1
# Environment (Pollution Prevention)                                  0
# General Appearance And Condition                                    0
# General Information                                                 0
# Maritime Security                                                   0
# Mooring                                                             1
# Navigation                                                          3
# Safety Management                                                   2
# ...

# %%
pd.crosstab(data['AreaOfConcern'], data['SeverityOfIncident'])
# Out:
# SeverityOfIncident                  High  Low  Medium
# AreaOfConcern
# Cargo And Ballast System              15   42      61
# Communication                          2    3       2
# Company Documents                      1    0       3
# Crew Management                        8   19      27
# Engine And Steering Compartments      25   49      90
# Environment (Pollution Prevention)     4    8      20
# General Appearance And Condition       5   21      24
# General Information                    0    6       2
# Maritime Security                      0    8       3
# Mooring                               14   79      93
# Navigation                            16   11      25
# Safety Management                     56  234     213
# Structurall Condition Pms              8    9      13
# Unknown                                6    7       4

# %%
data['DetailedExtentofDamageInjury'].head()
# Out:
# 0    MSB busbar damaged. Breaker connecting strip b...
# 1    Vessel was receiving bunkers at Western Anchor...
# 2    During the ISPS audit it was found that few of...
# 3                                                  NaN
# 4                                                  NaN
# Name: DetailedExtentofDamageInjury, dtype: object

# %%
data['DetailedExtentofDamageInjury'].dtype
# Out:
# dtype('O')

# %%
data['DetailedExtentofDamageInjury'].isnull().sum()
# Out:
# np.int64(206)

# %%
data['DetailedExtentofDamageInjury'] = data['DetailedExtentofDamageInjury'].fillna('Not Mentioned')

# %%
data['DetailedExtentofDamageInjury'] = data['DetailedExtentofDamageInjury'].str.strip()

# %%
data['DetailedExtentofDamageInjury'].unique()
# Out:
# array(['MSB busbar damaged. Breaker connecting strip bars melted. Leading to ME stoppage and blackout to repair.',
#        'Vessel was receiving bunkers at Western Anchorage Bravo Singapore. On poop  deck, crew was securing ropes on winches in preparation for sea, the duty AB  observed the small leakage in form of spray coming from the hydraulic inlet line of  mooring winch on stbd side just above FO vents. Duty officer was informed. Framo  power pack system stopped immediately, and Ch mate was instructed to inspect the  line and area for oil spill, It was observed that the leaking oil from hydraulic line was  dropping directly in to the fuel oil vent save all drip tray. Save all drip tray was plugged  and oil accumulated in the tray. Leaked oil was collected into the bucket and  transferred to engine room.',
# ...

# %%
data['DetailedExtentofDamageInjury'].value_counts(normalize=True) * 100
# Out:
# DetailedExtentofDamageInjury
# Not Mentioned                                                                                                                                                                                                                                14.599575
# NIL                                                                                                                                                                                                                                           0.425230
# NONE                                                                                                                                                                                                                                          0.283487
# ...

# %%
data['DetailedExtentofDamageInjury'] = data['DetailedExtentofDamageInjury'].replace(
    ['NIL','Nil','NONE','None','No Damage','No Injury'],
    'No Damage / Injury'
)

# %%
data['DetailedExtentofDamageInjury'] = data['DetailedExtentofDamageInjury'].replace(
    ['Not Mentioned'],
    'No Damage / Injury'
)

# %%
data['DetailedExtentofDamageInjury'].value_counts()
# Out:
# DetailedExtentofDamageInjury
# No Damage / Injury                                                                                                                                                                                                                           222
# 1 nos mooring rope damaged                                                                                                                                                                                                                     2
# Dust particle from Main Engine indicator valves accidentally flew into the left eye of Oiler John Christopher G. Regoso during blow off.                                                                                                       2
# ...

# %%
data['DirectCause'].head()
# Out:
# 0                       Loose conntion on MSB bus bars
# 1    Wear & Tear due to age of the pipeline & diffi...
# 2    Inefficient monitoring of visitors movement du...
# 3                                                  NaN
# 4    Can not run DG no.1.Because rack of fuel pump ...
# Name: DirectCause, dtype: object

# %%
data['DirectCause'].dtype
# Out:
# dtype('O')

# %%
data['DirectCause'].isnull().sum()
# Out:
# np.int64(330)

# %%
data['DirectCause'] = data['DirectCause'].fillna('Not Mentioned')

# %%
data['DirectCause'] = data['DirectCause'].str.strip()

# %%
data['DirectCause'] = data['DirectCause'].str.title()

# %%
data['DirectCause'].unique()
# Out:
# array(['Loose Conntion On Msb Bus Bars',
#        'Wear & Tear Due To Age Of The Pipeline & Difficult In Accessing For Maintenance & Inspection.',
#        'Inefficient Monitoring Of Visitors Movement During Dearture.',
#        ..., 'Under Investigation',
#        'Possible Loss Of Situational Awareness While Moving On Ladder From One Deck To Another.',
#        'Unsafe Movement And Lost Balance.'], shape=(1015,), dtype=object)

# %%
data['DirectCause'].value_counts().head(10)
# Out:
# DirectCause
# Not Mentioned                                                                                            330
# Nil                                                                                                       52
# Material Failure                                                                                           4
# Ref Attached Incident Report                                                                               3
# Non Compliance Of Procedure                                                                                2
# Material Failure Due To Ageing                                                                             2
# Lack Of Awareness.                                                                                         2
# Unsafe Condition                                                                                           2
# ...

# %%
import seaborn as sns

# %%
data['Proposedcorrectiveactions'].head()
# Out:
# 0    Complete MSB cleaning and retightening to be d...
# 1    Thorough inspection during PMS & replace any p...
# 2    Effective training to be carried out with all ...
# 3                                                  NaN
# 4    Change fuel pump (move fuel pump DG3 unit 5 to...
# Name: Proposedcorrectiveactions, dtype: object

# %%
data['Proposedcorrectiveactions'].isnull().sum()
# Out:
# np.int64(59)

# %%
data['Proposedcorrectiveactions'] = data['Proposedcorrectiveactions'].fillna('Not Mentioned')

# %%
data['Proposedcorrectiveactions'] = data['Proposedcorrectiveactions'].str.strip()

# %%
data['Proposedcorrectiveactions'] = data['Proposedcorrectiveactions'].astype(str)

# %%
data['CorrectiveAction_Lenght'] = data['Proposedcorrectiveactions'].str.strip()

# %%
data.drop(columns=['Correctiveaction_Lenght','CorrectiveAction_Lenght'], errors='ignore', inplace=True)

# %%
data.columns
# Out:
# Index(['Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate', 'Defect Status',
#        'Location', 'Port', 'IncidentDetails', 'IncidentEventDetails',
#        'ImmediateAction', 'Incident Category', 'Possibility Recurrence',
#        'AreaOfConcern', 'DetailedExtentofDamageInjury', 'DirectCause',
#        'Proposedcorrectiveactions', 'Corrective Action', 'LeariningPotential',
#        'SeverityOfIncident', 'Cause Analysis', 'Accident Details',
#        'LessionLearnt', 'ClosingNote', 'ClosingDate', 'Year', 'Month', 'Day'],
#       dtype='object')

# %%
data['CorrectiveAction_Length'] = data['Proposedcorrectiveactions'].astype(str).str.len()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.histplot(data['CorrectiveAction_Length'], bins=30)

plt.title("Corrective Action Description Length")

plt.xlabel("Length of Corrective Action")
plt.ylabel("Frequency")

plt.show()

# %%
data['CorrectiveAction_Length'].head()
# Out:
# 0     71
# 1    111
# 2     94
# 3     13
# 4     68
# Name: CorrectiveAction_Length, dtype: int64

# %%
data['Corrective Action'].head()
# Out:
# 0    Complete MSB cleaning and retightening to be d...
# 1        Pipeline permanently repaired on 05-Nov-2015.
# 2    All visitors passes to be checked/tallied by S...
# 3         To follow makers instructions on overhauling
# 4    Change fuel pump (move fuel pump DG3 unit 5 to...
# Name: Corrective Action, dtype: object

# %%
data['Corrective Action'].dtype
# Out:
# dtype('O')

# %%
data['Corrective Action'] = data['Corrective Action'].fillna('Not Mentioned')

# %%
data['Corrective Action'] = data['Corrective Action'].str.strip()

# %%
data['CorrectiveAction_Length'] = data['Corrective Action'].astype(str).str.len()

# %%
data[['Corrective Action','CorrectiveAction_Length']].head()
# Out:
#                                    Corrective Action  CorrectiveAction_Length
# 0  Complete MSB cleaning and retightening to be d...                       71
# 1      Pipeline permanently repaired on 05-Nov-2015.                       45
# 2  All visitors passes to be checked/tallied by S...                      128
# 3       To follow makers instructions on overhauling                       44
# 4  Change fuel pump (move fuel pump DG3 unit 5 to...                       68

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.histplot(data['CorrectiveAction_Length'], bins=30)

plt.title("Corrective Action Description Length")

plt.show()

# %%
data['Corrective Action'].str.contains('training', case=False, na=False).sum()
# Out:
# np.int64(90)

# %%
data['Corrective Action'].str.contains('maintenance', case=False, na=False).sum()
# Out:
# np.int64(10)

# %%
data['LeariningPotential'].head()
# Out:
# 0    Low
# 1    Low
# 2    Low
# 3    Low
# 4    Low
# Name: LeariningPotential, dtype: object

# %%
data['LeariningPotential'].isnull().sum()
# Out:
# np.int64(304)

# %%
data['LeariningPotential'] = data['LeariningPotential'].fillna('Unknown')

# %%
data['LeariningPotential'] = data['LeariningPotential'].str.strip()

# %%
data['LeariningPotential'].unique()
# Out:
# array(['Low', 'Medium', 'Unknown', 'High'], dtype=object)

# %%
data['LeariningPotential'].value_counts()
# Out:
# LeariningPotential
# Low        576
# Medium     488
# Unknown    304
# High        43
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='LeariningPotential', data=data)
plt.title("Learning Potential Distribution")
plt.xlabel("Learning Potential")
plt.ylabel("Number of Incidents")
plt.show()

# %%
pd.crosstab(data['LeariningPotential'], data['SeverityOfIncident'])
# Out:
# SeverityOfIncident  High  Low  Medium
# LeariningPotential
# High                  24    2      17
# Low                  107  364     105
# Medium                28   85     374
# Unknown                1   45      84

# %%
sns.countplot(x='SeverityOfIncident', hue='LeariningPotential', data=data)
# Out:
# <Axes: xlabel='SeverityOfIncident', ylabel='count'>

# %%
data['SeverityOfIncident'].head()
# Out:
# 0      High
# 1    Medium
# 2      High
# 3    Medium
# 4      High
# Name: SeverityOfIncident, dtype: object

# %%
data['SeverityOfIncident'].isnull().sum()
# Out:
# np.int64(175)

# %%
data['SeverityOfIncident'] = data['SeverityOfIncident'].fillna('Unknown')

# %%
data['SeverityOfIncident'] = data['SeverityOfIncident'].str.strip()

# %%
data['SeverityOfIncident'].unique()
# Out:
# array(['High', 'Medium', 'Low', 'Unknown'], dtype=object)

# %%
data['SeverityOfIncident'].value_counts()
# Out:
# SeverityOfIncident
# Medium     580
# Low        496
# Unknown    175
# High       160
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='SeverityOfIncident', data=data)
plt.title("Severity of Incident Distribution")
plt.xlabel("Severity Level")
plt.ylabel("Number of Incidents")
plt.show()

# %%
sns.countplot(x='Incident Category', hue='SeverityOfIncident', data=data)

plt.xticks(rotation=45)
plt.title("Incident Category vs Severity")

plt.show()

# %%
plt.figure(figsize=(10,8))

sns.countplot(y='AreaOfConcern', hue='SeverityOfIncident', data=data)

plt.title("Area of Concern vs Severity")

plt.show()

# %%
data['Cause Analysis'].head()
# Out:
# 0              Defective equipment, machinery or tools
# 1              Defective equipment, machinery or tools
# 2              Failure to follow rules and regulations
# 3    Failure to follow repair/maintenance instructions
# 4    Failure to follow repair/maintenance instructions
# Name: Cause Analysis, dtype: object

# %%
data['Cause Analysis'].dtype
# Out:
# dtype('O')

# %%
data['Cause Analysis'].isnull().sum()
# Out:
# np.int64(23)

# %%
data['Cause Analysis'] = data['Cause Analysis'].fillna('Not Mentioned')

# %%
data['Cause Analysis'] = data['Cause Analysis'].str.strip()

# %%
data['Cause Analysis'].head()
# Out:
# 0              Defective equipment, machinery or tools
# 1              Defective equipment, machinery or tools
# 2              Failure to follow rules and regulations
# 3    Failure to follow repair/maintenance instructions
# 4    Failure to follow repair/maintenance instructions
# Name: Cause Analysis, dtype: object

# %%
data['CauseAnalysis_Length'] = data['Cause Analysis'].astype(str).str.len()

# %%
data[['Cause Analysis','CauseAnalysis_Length']].head()
# Out:
#                                       Cause Analysis  CauseAnalysis_Length
# 0            Defective equipment, machinery or tools                    39
# 1            Defective equipment, machinery or tools                    39
# 2            Failure to follow rules and regulations                    39
# 3  Failure to follow repair/maintenance instructions                    49
# 4  Failure to follow repair/maintenance instructions                    49

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['CauseAnalysis_Length'], bins=30)
plt.title("Cause Analysis Description Length")
plt.show()

# %%
from collections import Counter
text = " ".join(data['Cause Analysis'])
words = text.split()
Counter(words).most_common(20)
# Out:
# [('Failure', 481),
#  ('to', 481),
#  ('or', 402),
#  ('Improper', 225),
#  ('machinery', 223),
#  ('follow', 207),
#  ('Other', 170),
#  ('substandard', 170),
#  ('use', 162),
#  ('conditions', 139),
#  ('handling', 134),
#  ('equipment', 132),
#  ('act(s)', 125),
#  ('position', 122),
#  ('for', 122),
#  ('task', 122),
#  ('repair/maintenance', 119),
#  ('instructions', 119),
#  ('secure', 116),
#  ('Adverse', 115)]

# %%
data['Cause Analysis'].str.contains('human', case=False, na=False).sum()
# Out:
# np.int64(0)

# %%
data['Cause Analysis'].str.contains('equipment', case=False, na=False).sum()
# Out:
# np.int64(223)

# %%
data['Accident Details'].head()
# Out:
# 0           Explosion-others
# 1                        NaN
# 2                        NaN
# 3    Other machinery failure
# 4    Other machinery failure
# Name: Accident Details, dtype: object

# %%
data['Accident Details'].dtype
# Out:
# dtype('O')

# %%
data['Accident Details'].isnull().sum()
# Out:
# np.int64(916)

# %%
data['Accident Details'] = data['Accident Details'].fillna('Not Mentioned')

# %%
data['Accident Details'] = data['Accident Details'].str.strip()

# %%
data['AccidentDetails_Length'] = data['Accident Details'].astype(str).str.len()

# %%
data[['Accident Details','AccidentDetails_Length']].head()
# Out:
#           Accident Details  AccidentDetails_Length
# 0         Explosion-others                      16
# 1            Not Mentioned                      13
# 2            Not Mentioned                      13
# 3  Other machinery failure                      23
# 4  Other machinery failure                      23

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['AccidentDetails_Length'], bins=30)
plt.title("Accident Details Description Length")
plt.show()

# %%
data['Accident Details'].str.contains('engine', case=False, na=False).sum()
# Out:
# np.int64(0)

# %%
data['Accident Details'].str.contains('crew', case=False, na=False).sum()
# Out:
# np.int64(0)

# %%
data['LessionLearnt'].head()
# Out:
# 0                                                  NaN
# 1                                                  NaN
# 2    Effective Monitoring of Visitor Passes and ade...
# 3                                                  NaN
# 4                                                  NaN
# Name: LessionLearnt, dtype: object

# %%
data['LessionLearnt'].dtype
# Out:
# dtype('O')

# %%
data['LessionLearnt'].isnull().sum()
# Out:
# np.int64(996)

# %%
data['LessionLearnt'] = data['LessionLearnt'].fillna('Not Mentioned')

# %%
data['LessionLearnt'] = data['LessionLearnt'].str.strip()

# %%
data['Lesson_Length'] = data['LessionLearnt'].astype(str).str.len()

# %%
data[['LessionLearnt','Lesson_Length']].head()
# Out:
#                                        LessionLearnt  Lesson_Length
# 0                                      Not Mentioned             13
# 1                                      Not Mentioned             13
# 2  Effective Monitoring of Visitor Passes and ade...             93
# 3                                      Not Mentioned             13
# 4                                      Not Mentioned             13

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['Lesson_Length'], bins=30)
plt.title("Lesson Learned Description Length")
plt.show()

# %%
data['LessionLearnt'].str.contains('safety', case=False, na=False).sum()
# Out:
# np.int64(20)

# %%
data['LessionLearnt'].str.contains('maintenance', case=False, na=False).sum()
# Out:
# np.int64(9)

# %%
data['ClosingNote'].head()
# Out:
# 0    Aux Blower Connecting strip bars were renewed ...
# 1    Tested & found satisfactory after permanent re...
# 2    Records of training attached and effective imp...
# 3    Makers instructions for overhauling to be foll...
# 4                                                  NaN
# Name: ClosingNote, dtype: object

# %%
data['ClosingNote'].isnull().sum()
# Out:
# np.int64(164)

# %%
data['ClosingNote'] = data['ClosingNote'].fillna('Not Mentioned')

# %%
data['ClosingNote'] = data['ClosingNote'].str.strip()

# %%
data['ClosingNote_Length'] = data['ClosingNote'].astype(str).str.len()

# %%
data[['ClosingNote','ClosingNote_Length']].head()
# Out:
#                                          ClosingNote  ClosingNote_Length
# 0  Aux Blower Connecting strip bars were renewed ...                  57
# 1  Tested & found satisfactory after permanent re...                  52
# 2  Records of training attached and effective imp...                  97
# 3  Makers instructions for overhauling to be foll...                  64
# 4                                      Not Mentioned                  13

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['ClosingNote_Length'], bins=30)
plt.title("Closing Note Description Length")
plt.show()

# %%
from collections import Counter

text = " ".join(data['ClosingNote'])

words = text.split()

Counter(words).most_common(20)
# Out:
# [('to', 881),
#  ('the', 841),
#  ('and', 659),
#  ('be', 475),
#  ('of', 427),
#  ('in', 338),
#  ('for', 246),
#  ('with', 235),
#  ('on', 189),
#  ('was', 171),
#  ('all', 169),
#  ('Not', 165),
#  ('Mentioned', 164),
#  ('is', 137),
#  ('The', 125),
#  ('out', 120),
#  ('by', 113),
#  ('closed', 112),
#  ('carried', 105),
#  ('as', 100)]

# %%
data['ClosingNote'].str.contains('repair', case=False, na=False).sum()
# Out:
# np.int64(24)

# %%
data['ClosingNote'].str.contains('inspection', case=False, na=False).sum()
# Out:
# np.int64(34)

# %%
data['ClosingDate'].head()
# Out:
# 0   2016-02-10
# 1   2015-11-26
# 2   2016-04-06
# 3   2015-12-10
# 4   2015-12-09
# Name: ClosingDate, dtype: datetime64[ns]

# %%
data['ClosingDate'] = pd.to_datetime(data['ClosingDate'], errors='coerce')

# %%
data['ClosingDate'].isnull().sum()
# Out:
# np.int64(205)

# %%
data['ClosingYear'] = data['ClosingDate'].dt.year
data['ClosingMonth'] = data['ClosingDate'].dt.month
data['ClosingDay'] = data['ClosingDate'].dt.day

# %%
data['ClosingMonth'] = data['ClosingDate'].dt.strftime('%B')

# %%
data['ClosingMonth'].value_counts().sort_index()
# Out:
# ClosingMonth
# April        127
# August        79
# December     109
# February     118
# January       93
# July         109
# June          82
# March        124
# May           89
# November     103
# October       81
# September     92
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='ClosingMonth', data=data)
plt.xticks(rotation=45)   # rotate labels
plt.title("Incidents Closed by Month")
plt.show()

# %%
data.groupby('ClosingYear').size()
# Out:
# ClosingYear
# 2015.0     11
# 2016.0    190
# 2017.0    263
# 2018.0    297
# 2019.0    302
# 2020.0    143
# dtype: int64

# %%
data.groupby('ClosingYear').size().plot(kind='bar')

plt.title("Incidents Closed per Year")
plt.xlabel("Year")
plt.ylabel("Number of Incidents")

plt.show()

# %%
data.columns
# Out:
# Index(['Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate', 'Defect Status',
#        'Location', 'Port', 'IncidentDetails', 'IncidentEventDetails',
#        'ImmediateAction', 'Incident Category', 'Possibility Recurrence',
#        'AreaOfConcern', 'DetailedExtentofDamageInjury', 'DirectCause',
#        'Proposedcorrectiveactions', 'Corrective Action', 'LeariningPotential',
#        'SeverityOfIncident', 'Cause Analysis', 'Accident Details',
#        'LessionLearnt', 'ClosingNote', 'ClosingDate', 'Year', 'Month', 'Day',
#        'CorrectiveAction_Length', 'CauseAnalysis_Length',
#        'AccidentDetails_Length', 'Lesson_Length', 'ClosingNote_Length',
#        'ClosingYear', 'ClosingMonth', 'ClosingDay'],
#       dtype='object')

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data['ClosingYear'] = data['ClosingYear'].astype('Int64')

# %%
data['ClosingDay'] = data['ClosingDay'].astype('Int64')

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data.columns
# Out:
# Index(['Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate', 'Defect Status',
#        'Location', 'Port', 'IncidentDetails', 'IncidentEventDetails',
#        'ImmediateAction', 'Incident Category', 'Possibility Recurrence',
#        'AreaOfConcern', 'DetailedExtentofDamageInjury', 'DirectCause',
#        'Proposedcorrectiveactions', 'Corrective Action', 'LeariningPotential',
#        'SeverityOfIncident', 'Cause Analysis', 'Accident Details',
#        'LessionLearnt', 'ClosingNote', 'ClosingDate', 'Year', 'Month', 'Day',
#        'CorrectiveAction_Length', 'CauseAnalysis_Length',
#        'AccidentDetails_Length', 'Lesson_Length', 'ClosingNote_Length',
#        'ClosingYear', 'ClosingMonth', 'ClosingDay'],
#       dtype='object')

# %%
data['Year'].head()
# Out:
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# Name: Year, dtype: int32

# %%
data['Year'].dtype
# Out:
# dtype('int32')

# %%
data['Year'].value_counts()
# Out:
# Year
# 2019    357
# 2018    313
# 2017    296
# 2016    211
# 2020    183
# 2015     51
# Name: count, dtype: int64

# %%
data['Year'].value_counts().sort_index()
# Out:
# Year
# 2015     51
# 2016    211
# 2017    296
# 2018    313
# 2019    357
# 2020    183
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Year', data=data)
plt.title("Incidents by Year")
plt.show()

# %%
data['Month'].value_counts()
# Out:
# Month
# December     147
# January      137
# February     137
# April        136
# March        128
# November     125
# May          118
# June         109
# October      101
# September     97
# July          90
# August        86
# Name: count, dtype: int64

# %%
month_order = ['January','February','March','April','May','June',
               'July','August','September','October','November','December']
plt.figure(figsize=(12,5))
sns.countplot(x='Month', data=data, order=month_order)
plt.xticks(rotation=45)
plt.title("Incidents by Month")
plt.show()

# %%
data['Day'].value_counts().sort_index()
# Out:
# Day
# 1     50
# 2     39
# 3     37
# 4     39
# 5     45
# 6     44
# 7     56
# 8     47
# 9     43
# 10    44
# 11    44
# 12    47
# 13    49
# 14    43
# 15    37
# 16    47
# 17    42
# 18    41
# 19    60
# 20    54
# 21    42
# 22    48
# 23    55
# 24    46
# 25    52
# 26    45
# 27    46
# 28    54
# 29    45
# 30    36
# 31    34
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,5))

sns.countplot(x='Day', data=data)

plt.title("Incidents by Day of Month")

plt.show()

# %%
pd.crosstab(data['Month'], data['Year'])
# Out:
# Year       2015  2016  2017  2018  2019  2020
# Month
# April         1    22    29    26    25    33
# August        3    13    20    18    32     0
# December     24    21    35    30    37     0
# February      0    13    24    32    17    51
# January       0     7    32    27    31    40
# July          1    11    19    29    30     0
# June          1    22    22    30    34     0
# March         0    18    19    30    25    36
# May           0    21    30    22    22    23
# November     15    23    26    20    41     0
# October       1    24    19    22    35     0
# September     5    16    21    27    28     0

# %%
month_order = ['January','February','March','April','May','June',
               'July','August','September','October','November','December']

data['Month'] = pd.Categorical(data['Month'], categories=month_order, ordered=True)

# %%
month_year = pd.crosstab(data['Month'], data['Year'])

# %%
plt.figure(figsize=(10,6))
sns.heatmap(month_year, annot=True, cmap="Blues", fmt='d')
plt.title("Incidents by Month and Year")
plt.xlabel("Year")
plt.ylabel("Month")
plt.show()

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data.columns
# Out:
# Index(['Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate', 'Defect Status',
#        'Location', 'Port', 'IncidentDetails', 'IncidentEventDetails',
#        'ImmediateAction', 'Incident Category', 'Possibility Recurrence',
#        'AreaOfConcern', 'DetailedExtentofDamageInjury', 'DirectCause',
#        'Proposedcorrectiveactions', 'Corrective Action', 'LeariningPotential',
#        'SeverityOfIncident', 'Cause Analysis', 'Accident Details',
#        'LessionLearnt', 'ClosingNote', 'ClosingDate', 'Year', 'Month', 'Day',
#        'CorrectiveAction_Length', 'CauseAnalysis_Length',
#        'AccidentDetails_Length', 'Lesson_Length', 'ClosingNote_Length',
#        'ClosingYear', 'ClosingMonth', 'ClosingDay'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# Vessel                            0
# RefNO                             0
# OccurrenceDate                    0
# ReportDate                        0
# Defect Status                     0
# Location                          0
# Port                              0
# IncidentDetails                   0
# IncidentEventDetails              0
# ImmediateAction                   0
# Incident Category                 0
# Possibility Recurrence            0
# AreaOfConcern                     0
# DetailedExtentofDamageInjury      0
# DirectCause                       0
# Proposedcorrectiveactions         0
# Corrective Action                 0
# LeariningPotential                0
# SeverityOfIncident                0
# Cause Analysis                    0
# Accident Details                  0
# LessionLearnt                     0
# ClosingNote                       0
# ClosingDate                     205
# Year                              0
# Month                             0
# ...

# %%
data['ClosingDate'] = data['ClosingDate'].fillna('Not Closed')

# %%
data['ClosingYear'] = data['ClosingYear'].fillna(0)
data['ClosingMonth'] = data['ClosingMonth'].fillna(0)
data['ClosingDay'] = data['ClosingDay'].fillna(0)

# %%
data.isna().sum()
# Out:
# Vessel                          0
# RefNO                           0
# OccurrenceDate                  0
# ReportDate                      0
# Defect Status                   0
# Location                        0
# Port                            0
# IncidentDetails                 0
# IncidentEventDetails            0
# ImmediateAction                 0
# Incident Category               0
# Possibility Recurrence          0
# AreaOfConcern                   0
# DetailedExtentofDamageInjury    0
# DirectCause                     0
# Proposedcorrectiveactions       0
# Corrective Action               0
# LeariningPotential              0
# SeverityOfIncident              0
# Cause Analysis                  0
# Accident Details                0
# LessionLearnt                   0
# ClosingNote                     0
# ClosingDate                     0
# Year                            0
# Month                           0
# Day                             0
# ...

# %%
data.to_csv('cleaned_AID_data.csv', index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dhana'

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data.isna().sum()
# Out:
# Vessel                          0
# RefNO                           0
# OccurrenceDate                  0
# ReportDate                      0
# Defect Status                   0
# Location                        0
# Port                            0
# IncidentDetails                 0
# IncidentEventDetails            0
# ImmediateAction                 0
# Incident Category               0
# Possibility Recurrence          0
# AreaOfConcern                   0
# DetailedExtentofDamageInjury    0
# DirectCause                     0
# Proposedcorrectiveactions       0
# Corrective Action               0
# LeariningPotential              0
# SeverityOfIncident              0
# Cause Analysis                  0
# Accident Details                0
# LessionLearnt                   0
# ClosingNote                     0
# ClosingDate                     0
# Year                            0
# Month                           0
# Day                             0
# ...

# %%
data.to_csv(r'C:\Users\dhana\OneDrive\Desktop\cleaned_AID_data.csv', index=False)

# %%
data.to_csv('cleaned_AID_data.csv', index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dhana'

# %%
data.columns
# Out:
# Index(['Vessel', 'RefNO', 'OccurrenceDate', 'ReportDate', 'Defect Status',
#        'Location', 'Port', 'IncidentDetails', 'IncidentEventDetails',
#        'ImmediateAction', 'Incident Category', 'Possibility Recurrence',
#        'AreaOfConcern', 'DetailedExtentofDamageInjury', 'DirectCause',
#        'Proposedcorrectiveactions', 'Corrective Action', 'LeariningPotential',
#        'SeverityOfIncident', 'Cause Analysis', 'Accident Details',
#        'LessionLearnt', 'ClosingNote', 'ClosingDate', 'Year', 'Month', 'Day',
#        'CorrectiveAction_Length', 'CauseAnalysis_Length',
#        'AccidentDetails_Length', 'Lesson_Length', 'ClosingNote_Length',
#        'ClosingYear', 'ClosingMonth', 'ClosingDay'],
#       dtype='object')

# %%
data['ClosingDate'].head()
# Out:
# 0    2016-02-10 00:00:00
# 1    2015-11-26 00:00:00
# 2    2016-04-06 00:00:00
# 3    2015-12-10 00:00:00
# 4    2015-12-09 00:00:00
# Name: ClosingDate, dtype: object

# %%
data['ClosingDate'] = pd.to_datetime(data['ClosingDate'], errors='coerce').dt.strftime('%Y-%m-%d')

# %%
data['ClosingDate'].head()
# Out:
# 0    2016-02-10
# 1    2015-11-26
# 2    2016-04-06
# 3    2015-12-10
# 4    2015-12-09
# Name: ClosingDate, dtype: object

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...

# %%
data.isna().sum()
# Out:
# Vessel                            0
# RefNO                             0
# OccurrenceDate                    0
# ReportDate                        0
# Defect Status                     0
# Location                          0
# Port                              0
# IncidentDetails                   0
# IncidentEventDetails              0
# ImmediateAction                   0
# Incident Category                 0
# Possibility Recurrence            0
# AreaOfConcern                     0
# DetailedExtentofDamageInjury      0
# DirectCause                       0
# Proposedcorrectiveactions         0
# Corrective Action                 0
# LeariningPotential                0
# SeverityOfIncident                0
# Cause Analysis                    0
# Accident Details                  0
# LessionLearnt                     0
# ClosingNote                       0
# ClosingDate                     205
# Year                              0
# Month                             0
# ...

# %%
data['ClosingDate'] = data['ClosingDate'].fillna('Not Closed')

# %%
data.isna().sum()
# Out:
# Vessel                          0
# RefNO                           0
# OccurrenceDate                  0
# ReportDate                      0
# Defect Status                   0
# Location                        0
# Port                            0
# IncidentDetails                 0
# IncidentEventDetails            0
# ImmediateAction                 0
# Incident Category               0
# Possibility Recurrence          0
# AreaOfConcern                   0
# DetailedExtentofDamageInjury    0
# DirectCause                     0
# Proposedcorrectiveactions       0
# Corrective Action               0
# LeariningPotential              0
# SeverityOfIncident              0
# Cause Analysis                  0
# Accident Details                0
# LessionLearnt                   0
# ClosingNote                     0
# ClosingDate                     0
# Year                            0
# Month                           0
# Day                             0
# ...

# %%
data
# Out:
#               Vessel                        RefNO      OccurrenceDate  \
# 0        KAILASH GAS          ADI/KAILA/2015/04/4 2015-04-13 09:15:51
# 1     FALCON VICTORY          ADI/VICTO/2015/07/2 2015-07-19 13:00:51
# 2      CALA PINGUINO            ADI/PIN/2015/11/6 2015-11-05 11:39:31
# 3       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/27 2015-09-29 12:32:00
# 4       EAST BANGKOK  ADI/BANGK-SMPL-C/2015/11/28 2015-09-11 13:04:00
# ...              ...                          ...                 ...
# 1406   MAERSK EDIRNE           ADI/MEDN/2020/05/1 2020-05-10 12:30:10
# 1407  SOUTHERN GLORY           ADI/SOGL/2020/05/1 2020-05-21 15:00:10
# 1408   LOWLANDS BLUE           ADI/LLBL/2020/05/2 2020-01-20 17:30:10
# 1409  VELOS SAPPHIRE           ADI/VESA/2020/05/4 2020-05-18 07:21:18
# 1410       BW KIZOKU           ADI/BWKI/2020/06/1 2020-05-29 16:18:33
#
#                ReportDate Defect Status Location  \
# 0     2015-04-13 04:02:44        Closed      Sea
# ...
